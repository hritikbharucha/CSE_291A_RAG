# %%
import pyarrow as pa
import pyarrow.ipc as ipc

# Path to your Arrow file
file_path = "data/WikipediaSTEM270K/data-00000-of-00004.arrow"

# Open and read the file
with pa.memory_map(file_path, "r") as source:
    reader = ipc.RecordBatchFileReader(source)
    table = reader.read_all()

print(table)
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# Cell In[1], line 9
#       7 # Open and read the file
#       8 with pa.memory_map(file_path, "r") as source:
# ----> 9     reader = ipc.RecordBatchFileReader(source)
#      10     table = reader.read_all()
#      12 print(table)
#
# File ~/miniforge3/envs/cse291-rag/lib/python3.11/site-packages/pyarrow/ipc.py:115, in RecordBatchFileReader.__init__(self, source, footer_offset, options, memory_pool)
#     112 def __init__(self, source, footer_offset=None, *, options=None,
#     113              memory_pool=None):
#     114     options = _ensure_default_ipc_read_options(options)
# --> 115     self._open(source, footer_offset=footer_offset,
#     116                options=options, memory_pool=memory_pool)
#
# File ~/miniforge3/envs/cse291-rag/lib/python3.11/site-packages/pyarrow/ipc.pxi:1128, in pyarrow.lib._RecordBatchFileReader._open()
#
# File ~/miniforge3/envs/cse291-rag/lib/python3.11/site-packages/pyarrow/error.pxi:155, in pyarrow.lib.pyarrow_internal_check_status()
#
# File ~/miniforge3/envs/cse291-rag/lib/python3.11/site-packages/pyarrow/error.pxi:92, in pyarrow.lib.check_status()
#
# ArrowInvalid: Not an Arrow file
